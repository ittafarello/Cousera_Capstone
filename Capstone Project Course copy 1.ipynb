# %%
from IPython.core.display import HTML
htm = open("custom.css").read()
HTML(htm)
# Out:
# <style>
# #notebook-container {
#     padding: 15px;
#     background-color: #F8F8FF;
#     min-height: 0;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
#     box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.3);
# }
# .notebook_app {
#     background-color: GhostWhite;
# }
# body #header{
# background-color: #F8F8FF;
# }
# .column-66 {
#   float: left;
#   width: 66.66666%;
#   padding: 20px;
# }
#
# .column-33 {
#   float: left;
#   width: 33.33333%;
#   padding: 20px;
# }
#
# * {
#   box-sizing: border-box;
# }
#
# .row {
#   display: flex;
# }
#
# .column {
#   flex: 50%;
#   padding: 10px;
# }
#
# </style>

# %% [markdown]
# <h1 style="text-align: center">My Journey into Data Science</h1>

# %% [markdown]
# ![JourneyToaTransformation_small.jpg](attachment:JourneyToaTransformation_small.jpg)

# %% [markdown]
# ***

# %% [markdown]
# <div class="row">
#   <div class="column">
#     <h2 style="text-align: center; font-family: Comic Sans MS">"What can I do to transform myself into a new being?"</h2>
#   </div>
#   <div class="column">
#     <img src="https://cdn.pixabay.com/photo/2016/03/21/20/04/butterflies-1271450_960_720.jpg" alt="Buttlerfly" style="width:350px;height:300px;">
#   </div>
# </div>

# %% [markdown]
# <div style="width: 100%;background-color: white;box-shadow: 0 4px 8px 0 rgba(0, 0, 0, 0.2), 0 6px 20px 0 rgba(0, 0, 0, 0.19);margin-bottom: 25px;">
#   <img src="https://cdn.pixabay.com/photo/2016/03/21/20/04/butterflies-1271450_960_720.jpg" alt="Buttlerfly" style="width:50%;">
#   <div style="font-family: Comic Sans MS; color: #00FFFF; position: absolute; top: 10%; left: 50%; transform: translate(-50%, -50%); font-size: 24px;">
#   <p>"What can I do to transform myself into a new being?"</p>
#   </div>
# </div>

# %%
position: absolute; top: 50%; left: 50%; transform: translate(-50%, -50%); font-size: 18px;
                    <div style="text-align: center;padding: 10px 20px">
                    
                    
                    
                    text-align: center; color: #4CAF50;
